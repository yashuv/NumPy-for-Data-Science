# %% [markdown]
# # Assignment Set 1 - Module Creating Arrays And Solution:

# %%
import numpy as np

# %% [markdown]
# ### Q1.  Create a 2x2x2 3-D array containing total 8 elements.

# %%
arr_3d = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(arr_3d)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %% [markdown]
# ### Q2.  Replace the 1st element of the above 3-D array with 10

# %%
arr_3d[0,0,0] = 10
arr_3d
# Out:
# array([[[10,  2],
#         [ 3,  4]],
#
#        [[ 5,  6],
#         [ 7,  8]]])

# %% [markdown]
# ### 3.  Check the shape and dimensions of the above 3-D array

# %%
print('shape :',arr_3d.shape)
print('dimensions :',arr_3d.ndim)
# Out:
# shape : (2, 2, 2)
# dimensions : 3

# %% [markdown]
# ### 4. Export the above array

# %%
np.save('output.npy', arr_3d)

# %% [markdown]
# ### 5. Import the array from given url
#
# ``` url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data' ```

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

data = np.genfromtxt(url,delimiter=',', dtype='float')
data
