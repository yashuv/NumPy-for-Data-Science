# %% [markdown]
# **Assignment 3 With Solotion On Data Manipulation**

# %%
import numpy as np

# %% [markdown]
# 1. Find the mean, median, standard deviation of iris's sepallength (1st column)
#
# ```
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# iris = np.genfromtxt(url, delimiter=',', dtype='object')
# ```

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = np.genfromtxt(url, delimiter=',', dtype='object')

sepallength = iris[:,0].astype('float')

# %% [markdown]
# Calculations:

# %%
print('Mean : ', np.mean(sepallength))
print('\n Median : ', np.median(sepallength))
print(' \n Standard Deviation : ', np.std(sepallength))

# %% [markdown]
# 2. Find the Coefficient of Variation  of iris's sepallength (1st column)
#
# ```
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# iris = np.genfromtxt(url, delimiter=',', dtype='object')
# ```

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = np.genfromtxt(url, delimiter=',', dtype='object')
sepallength = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0])

print('Coeff. of variation : ',np.std(sepallength) / np.mean(sepallength))
# Out:
# Coeff. of variation :  0.14123809899346393

# %% [markdown]
# 3. Fill the missing values with median of the columns in iris dataset
#
# ```
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# iris_2d = np.genfromtxt(url, delimiter=',', dtype='float')
# iris_2d[np.random.randint(150, size=20), np.random.randint(4, size=20)] = np.nan
# ```

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_2d = np.genfromtxt(url, delimiter=',', dtype='float')


iris_2d[np.random.randint(150, size=20), np.random.randint(4, size=20)] = np.nan
iris_2d[:10]

# %%
# soln
iris_2d[np.isnan(iris_2d)] = np.nanmedian(iris_2d).round(2)
iris_2d

# %% [markdown]
# 4. Reshape the 3-D array to 4x2 array
#
# ```
# array_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
# ```

# %%
array_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
array_3d.shape
# Out:
# (2, 2, 2)

# %%
# soln
array_3d.reshape(4, 2)

# %% [markdown]
# 5. Flatten the 3-D array
#
# ```
# array_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
# ```

# %%
# Solution
array_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
array_flatened = array_3d.flatten()
array_flatened
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %% [markdown]
# 6. Create an equally spaced numpy array of length 20 having values between 1 and 100. Print the stepsize between two values as well.

# %%
np.linspace(1, 100, 20, retstep=True)

# %% [markdown]
# 7. Stack the arrays a and b horizontally.
#
# ```
# a = np.arange(10).reshape(2,-1)
# b = np.repeat(1, 10).reshape(2,-1)
# ```

# %%
a = np.arange(10).reshape(2,-1)
b = np.repeat(1, 10).reshape(2,-1)

np.hstack((a, b))
# Out:
# array([[0, 1, 2, 3, 4, 1, 1, 1, 1, 1],
#        [5, 6, 7, 8, 9, 1, 1, 1, 1, 1]])

# %% [markdown]
# 8. Split the iris dataset into multiple small arrays having 10 rows each
#
# ```
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0, 1, 2, 3])
# ```

# %%
# soln
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0, 1, 2, 3])

np.vsplit(iris_2d, 10)
